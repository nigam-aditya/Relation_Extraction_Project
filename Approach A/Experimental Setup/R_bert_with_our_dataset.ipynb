# %%
# !pip3 install vncorenlp
# !pip3 install fairseq
# !pip3 install fastBPE
# !pip3 install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.48.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)

# %%
from transformers import *
import torch
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import train_test_split
import os
from tqdm import tqdm, trange
# Out:
# GroupViT models are not usable since `tensorflow_probability` can't be loaded. It seems you have `tensorflow_probability` installed with the wrong tensorflow version.Please try to reinstall it following the instructions here: https://github.com/tensorflow/probability.
# TAPAS models are not usable since `tensorflow_probability` can't be loaded. It seems you have `tensorflow_probability` installed with the wrong tensorflow version. Please try to reinstall it following the instructions here: https://github.com/tensorflow/probability.

# %% [markdown]
# R-BERT model architecture similar to the one proposed in [1], reimplementation inspired by [2]
#
# [1] Enriching Pre-trained Language Model with Entity Information for
# Relation Classification, Shanchan Wu, Yifan He, https://arxiv.org/pdf/1905.08284v1
#
# [2] Reimplement R-BERT from "Enriching Pre-trained Language Model with Entity Information for Relation Classification" paper, https://github.com/heraclex12/R-BERT-Relation-Classification

# %%
class FCLayer(torch.nn.Module):
  def __init__(self, input_dim, output_dim, dropout_rate=0., use_activation=True):
    super(FCLayer, self).__init__()
    self.use_activation = use_activation
    self.dropout = torch.nn.Dropout(dropout_rate)
    self.linear = torch.nn.Linear(input_dim, output_dim)
    self.tanh = torch.nn.Tanh()

  def forward(self, x):
    x = self.dropout(x)
    if self.use_activation:
      x = self.tanh(x)
    return self.linear(x)

# %%
class RBERT(BertPreTrainedModel):
  base_model_prefix = "roberta"
  config_class = RobertaConfig
  #pretrained_model_archive_map = ROBERTA_PRETRAINED_CONFIG_ARCHIVE_MAP
  def __init__(self, config, args):
    super(RBERT, self).__init__(config)
    self.roberta = RobertaModel(config=config)
    self.num_labels = config.num_labels
    self.cls_fc_layer = FCLayer(config.hidden_size, config.hidden_size, args['DROPOUT_RATE'])
    self.e1_fc_layer = FCLayer(config.hidden_size, config.hidden_size, args['DROPOUT_RATE'])
    self.e2_fc_layer = FCLayer(config.hidden_size, config.hidden_size, args['DROPOUT_RATE'])
    self.label_classifier = FCLayer(config.hidden_size * 3, self.num_labels, args['DROPOUT_RATE'], use_activation=False)

  @staticmethod
  def entity_average(hidden_output, e_mask):
    e_mask_unqueeze = e_mask.unsqueeze(1)
    length_tensor = (e_mask != 0).sum(dim=1).unsqueeze(1)

    sum_vector = torch.bmm(e_mask_unqueeze.float(), hidden_output).squeeze(1)
    avg_vector = sum_vector.float() / length_tensor.float()
    return avg_vector

  def forward(self, input_ids, attention_mask, labels, e1_mask, e2_mask):
    outputs = self.roberta(input_ids, attention_mask=attention_mask)
    sequence_output = outputs[0]
    pooled_output = outputs[1]

    e1_h = self.entity_average(sequence_output, e1_mask)
    e2_h = self.entity_average(sequence_output, e2_mask)

    pooled_output = self.cls_fc_layer(pooled_output)
    e1_h = self.e1_fc_layer(e1_h)
    e2_h = self.e2_fc_layer(e2_h)

    concat_h = torch.cat([pooled_output, e1_h, e2_h], dim=-1)
    logits = self.label_classifier(concat_h)

    outputs = (logits, ) + outputs[2:]

    if labels is not None:
      if self.num_labels == 1:
        loss_fct = torch.nn.MSELoss()
        loss = loss_fct(logits.view(-1), labels.view(-1))
      else:
        loss_fct = torch.nn.CrossEntropyLoss()
        loss = loss_fct(logits.view(-1, self.num_labels), labels.view(-1))

      outputs = (loss,) + outputs
    return outputs

# %% [markdown]
# Loading our distant supervised dataset and the official test dataset

# %%
train_df = pd.read_csv("dataset.csv", header=None, names=["label", "text"])
test_df = pd.read_csv('test.tsv', sep='\t', header=None, names=['label', 'text'])
labels = pd.read_fwf('label.txt', header=None, names=['label'])
train_df.head()
# Out:
#                       label                                               text
# 0    Component-Whole(e2,e1)  the system described above has its greatest ap...
# 1                     Other  the <e1> child </e1> was carefully wrapped and...
# 2  Instrument-Agency(e2,e1)  the <e1> author </e1> keygen uses <e2> disasse...
# 3                     Other  misty <e1> ridge </e1> uprises from the <e2> s...
# 4  Member-Collection(e1,e2)  the <e1> student </e1> <e2> association </e2> ...

# %%
def seed_everything(SEED):
  np.random.seed(SEED)
  torch.manual_seed(SEED)
  torch.cuda.manual_seed(SEED)
  torch.backends.cudnn.deterministic = True

if torch.cuda.is_available():
  device = torch.device("cuda")
  print("We will use the GPU:", torch.cuda.get_device_name())
else:
  device = torch.device("cpu")
  print("We will use the CPU.")

args = {
    'NUM_LABELS' : len(labels),
    'DROPOUT_RATE' : 0.1,
    'LEARNING_RATE' : 2e-5,
    'EPOCHS' : 5,
    'MAX_SEQUENCE_LENGTH' : 384,
    'BATCH_SIZE' : 16,
    'ADAM_EPSILON' : 1e-8,
    'GRADIENT_ACCUMULATION_STEPS' : 1,
    'MAX_GRAD_NORM' : 1.0,
    'LOGGING_STEPS' : 250,
    'SAVE_STEPS' : 250,
    'WEIGHT_DECAY' : 0.0,
    'NUM_WARMUP_STEPS' : 0,
}
# Out:
# We will use the GPU: Tesla T4

# %% [markdown]
# Modified function for filtering usable sentences, entity tags insertion and entity masks for R-bert approach.

# %%
def convert_lines(df, label_indexes, max_seq_len, tokenizer, cls_token='[CLS]',
                  sep_token='[SEP]', pad_token=0, add_sep_token=False, mask_padding_with_zero=True):
  input_ids = []
  attention_masks = []
  e1_masks = []
  e2_masks = []
  labels = []
  print("Converting sentence...")

  # Keep track of valid sentences
  valid_sentences = []

  for row in df.itertuples():
    if (row.Index % 5000 == 0 and row.Index > 0) or row.Index == len(df) - 1:
      print('Parsing {} of {}'.format(row.Index + 1, len(df)))

    # Preserve special tokens by splitting the text manually
    text = row.text.lower()
    text = text.replace("<e1>", " <e1> ").replace("</e1>", " </e1> ").replace("<e2>", " <e2> ").replace("</e2>", " </e2> ")
    tokens = tokenizer.tokenize(text)

    try:  # Handle cases where special tokens are missing
        e11_p = tokens.index("<e1>")
        e12_p = tokens.index("</e1>")
        e21_p = tokens.index("<e2>")
        e22_p = tokens.index("</e2>")

        # If all special tokens are found, add the sentence to the valid list
        valid_sentences.append(row)
    except ValueError:
        print(f"Skipping sentence due to missing special tokens: {row.text}")
        continue  # Skip to the next sentence

  # Process only valid sentences
  for row in valid_sentences:

    tokens = tokenizer.tokenize(row.text.lower())

    e11_p = tokens.index("<e1>")
    e12_p = tokens.index("</e1>")
    e21_p = tokens.index("<e2>")
    e22_p = tokens.index("</e2>")

    # Replace token
    tokens[e11_p] = '$'
    tokens[e12_p] = '$'
    tokens[e21_p] = '#'
    tokens[e22_p] = '#'

    # Add 1 because of the [CLS] token
    e11_p += 1
    e12_p += 1
    e21_p += 1
    e22_p += 1

    # Account for [CLS] and [SEP] with "2" and with "3" for RoBERTa
    if add_sep_token:
      special_tokens_count = 2
    else:
      special_tokens_count = 1

    if len(tokens) > max_seq_len - special_tokens_count:
      tokens = tokens[:(max_seq_len - special_tokens_count)]

    if add_sep_token:
      tokens += [sep_token]

    tokens = [cls_token] + tokens

    input_id = tokenizer.convert_tokens_to_ids(tokens)
    attention_mask = [1 if mask_padding_with_zero else 0] * len(input_id)

    padding_length = max_seq_len - len(input_id)
    input_id = input_id + ([pad_token] * padding_length)
    attention_mask = attention_mask + ([0 if mask_padding_with_zero else 1] * padding_length)

    e1_mask = [0] * len(attention_mask)
    e2_mask = [0] * len(attention_mask)

    for i in range(e11_p, e12_p + 1):
      e1_mask[i] = 1
    for i in range(e21_p, e22_p + 1):
      e2_mask[i] = 1

    assert len(input_id) == max_seq_len, "Error with input length {} vs {}".format(len(input_id), max_seq_len)
    assert len(attention_mask) == max_seq_len, "Error with attention mask length {} vs {}".format(len(attention_mask), max_seq_len)

    input_ids.append(input_id)
    attention_masks.append(attention_mask)
    labels.append(label_indexes.index[label_indexes.label == row.label][0])
    e1_masks.append(e1_mask)
    e2_masks.append(e2_mask)


  print(f"\nNumber of sentences left after removing invalid ones: {len(valid_sentences)}")
  dataset = torch.utils.data.TensorDataset(torch.tensor(input_ids, dtype=torch.long),
                          torch.tensor(attention_masks, dtype=torch.long),
                          torch.tensor(labels, dtype=torch.long),
                          torch.tensor(e1_masks, dtype=torch.long),
                          torch.tensor(e2_masks, dtype=torch.long))
  return dataset

# %% [markdown]
# Tokenization and model loading

# %%
ADDITIONAL_SPECIAL_TOKENS = ["<e1>", "</e1>", "<e2>", "</e2>"]
def load_model(args, mode='en'):
  tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
  tokenizer.add_special_tokens({"additional_special_tokens" : ADDITIONAL_SPECIAL_TOKENS})

  config = RobertaConfig.from_pretrained('roberta-base', num_labels = args['NUM_LABELS'])
  model = RBERT.from_pretrained('roberta-base', config=config, args=args)
  model.resize_token_embeddings(len(tokenizer))
  model.to(device)
  return config, tokenizer, model

seed_everything(42)
config, tokenizer, model = load_model(args)
# Out:
# loading file vocab.json from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/e2da8e2f811d1448a5b465c236feacd80ffbac7b/vocab.json
# loading file merges.txt from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/e2da8e2f811d1448a5b465c236feacd80ffbac7b/merges.txt
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/e2da8e2f811d1448a5b465c236feacd80ffbac7b/tokenizer_config.json
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/e2da8e2f811d1448a5b465c236feacd80ffbac7b/tokenizer.json
# loading file chat_template.jinja from cache at None
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/e2da8e2f811d1448a5b465c236feacd80ffbac7b/config.json
# Model config RobertaConfig {
#   "_name_or_path": "roberta-base",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.48.3",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/e2da8e2f811d1448a5b465c236feacd80ffbac7b/config.json
# Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4",
#     "5": "LABEL_5",
#     "6": "LABEL_6",
#     "7": "LABEL_7",
#     "8": "LABEL_8",
#     "9": "LABEL_9",
#     "10": "LABEL_10",
#     "11": "LABEL_11",
#     "12": "LABEL_12",
#     "13": "LABEL_13",
#     "14": "LABEL_14",
#     "15": "LABEL_15",
#     "16": "LABEL_16",
#     "17": "LABEL_17",
#     "18": "LABEL_18"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_10": 10,
#     "LABEL_11": 11,
#     "LABEL_12": 12,
#     "LABEL_13": 13,
#     "LABEL_14": 14,
#     "LABEL_15": 15,
#     "LABEL_16": 16,
#     "LABEL_17": 17,
#     "LABEL_18": 18,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4,
#     "LABEL_5": 5,
#     "LABEL_6": 6,
#     "LABEL_7": 7,
#     "LABEL_8": 8,
#     "LABEL_9": 9
#   },
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.48.3",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/e2da8e2f811d1448a5b465c236feacd80ffbac7b/model.safetensors
# Some weights of the model checkpoint at roberta-base were not used when initializing RBERT: ['lm_head.bias', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RBERT from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RBERT from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RBERT were not initialized from the model checkpoint at roberta-base and are newly initialized: ['cls_fc_layer.linear.bias', 'cls_fc_layer.linear.weight', 'e1_fc_layer.linear.bias', 'e1_fc_layer.linear.weight', 'e2_fc_layer.linear.bias', 'e2_fc_layer.linear.weight', 'label_classifier.linear.bias', 'label_classifier.linear.weight', 'roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embedding dimension will be 50269. This might induce some performance reduction as *Tensor Cores* will not be available. For more details about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc

# %% [markdown]
# Training and Test data processing

# %%
train_dataset = convert_lines(train_df, labels, args['MAX_SEQUENCE_LENGTH'], tokenizer, cls_token='<s>', sep_token='</s>', pad_token=1)
test_dataset = convert_lines(test_df, labels, args['MAX_SEQUENCE_LENGTH'], tokenizer, cls_token='<s>', sep_token='</s>', pad_token=1)

train_sampler = torch.utils.data.RandomSampler(train_dataset)
train_loader = torch.utils.data.DataLoader(train_dataset, sampler=train_sampler, batch_size=args['BATCH_SIZE'])

test_sampler = torch.utils.data.SequentialSampler(test_dataset)
test_loader = torch.utils.data.DataLoader(test_dataset, sampler=test_sampler, batch_size=args['BATCH_SIZE'] * 2)
# Out:
# Converting sentence...
# Skipping sentence due to missing special tokens: people have been moving back into <e2> downtown </e2>
# Skipping sentence due to missing special tokens: even commercial <e1> networks </e1> have moved into highdefinition broadcast
# Skipping sentence due to missing special tokens: suicide one the leading causes <e2> death </e2> among preadolescents and teens and victims bullying are increased risk for committing suicide
# Skipping sentence due to missing special tokens: newspapers swap content via widgets with the help the newsgator <e2> service </e2>
# Skipping sentence due to missing special tokens: calluses are caused improperly fitting shoes <e2> skin </e2> abnormality
# Skipping sentence due to missing special tokens: adults use <e2> drugs </e2> for this purpose
# Skipping sentence due to missing special tokens: leakage and fire caused due <e2> corrosion </e2> bypass piping for recirculation gas fuel oil desulphurization unit
# Skipping sentence due to missing special tokens: this plays games portable <e2> console </e2>
# Skipping sentence due to missing special tokens: chestnut <e2> flour </e2> was more common than wheat <e2> flour </e2> the italian alps century ago
# Skipping sentence due to missing special tokens: chemical weapons have been dropped into the <e2> lake </e2>
# Skipping sentence due to missing special tokens: people have travelled into <e2> space </e2> but not the deep ocean
# Skipping sentence due to missing special tokens: beaver <e2> dams </e2> are created protection against predators such coyotes wolves and bears and provide easy access food during winter
# Skipping sentence due to missing special tokens: initially the calibrates the microscope with fluorescence lifetime <e2> standard </e2> positioned the sample plane
# Skipping sentence due to missing special tokens: positions were denoted <e2> black </e2> dots along the tracks the adjacent numbers indicating the day the month
# Skipping sentence due to missing special tokens: contractions the diaphragm are caused stimulation the vagus nerve either the brain <e2> irritation </e2> anywhere along the length the nerve
# Skipping sentence due to missing special tokens: governments frightened losing votes resolved the crisis through <e2> subsidization </e2>
# Skipping sentence due to missing special tokens: the <e1> rope </e1> the prayerbell was there perfect state and coiled
# Skipping sentence due to missing special tokens: this process passes health <e1> gene </e1> the next <e1> gene </e1>ration
# Skipping sentence due to missing special tokens: mobile lost the ocean was found cod <e2> belly </e2>
# Skipping sentence due to missing special tokens: fish swim <e2> shoal </e2> but they fall one one
# Skipping sentence due to missing special tokens: cruisers and large yachts have much more sophisticated <e2> fittings </e2> that that require more skills
# Skipping sentence due to missing special tokens: cardiovascular disease one the leading causes <e2> morbidity </e2> and mortality the well the developed and the developing world
# Skipping sentence due to missing special tokens: dizziness from nasal and <e2> sinus </e2> pressure usually can seen good nasal examination and the <e2> sinus </e2>es
# Skipping sentence due to missing special tokens: feedback defined earlier this <e2> chapter </e2> information that can used modify maintain previous behaviours
# Skipping sentence due to missing special tokens: billions flow into unit trustlinked <e2> products </e2>
# Skipping sentence due to missing special tokens: blood arrives from the <e2> animal </e2> via suitable tubing and enters the pump
# Skipping sentence due to missing special tokens: asparagus natural cure for <e2> cancer </e2>
# Skipping sentence due to missing special tokens: cold air the surface moved southward into the <e2> mountains </e2> colorado
# Skipping sentence due to missing special tokens: peanut butter <e2> cookies </e2> are simply <e2> cookies </e2> that use peanut butter one the ingredients
# Skipping sentence due to missing special tokens: diabetes mellitus one the leading causes irreversible <e2> blindness </e2> worldwide and the united states
# Skipping sentence due to missing special tokens: flowers are carried into the <e2> chapel </e2>
# Skipping sentence due to missing special tokens: poems are published this <e2> site </e2> purely for educational reasons for the purpose information and with good intentions
# Skipping sentence due to missing special tokens: students locate these cities the large map with assistance from the teacher marking them with colored <e2> pushpins </e2>
# Skipping sentence due to missing special tokens: cigarettes are used <e2> women </e2> order relax avoid gaining weight and appear attractive mature and feminine
# Skipping sentence due to missing special tokens: bitewing xrays are used <e2> dentists </e2> order determine any cavities exist within the mouth
# Skipping sentence due to missing special tokens: the <e1> session </e1> discussed about interloans performance sets
# Skipping sentence due to missing special tokens: preeclampsia still one the leading causes maternal <e2> mortality </e2>
# Skipping sentence due to missing special tokens: alcohol substance abuse and poverty all lead <e2> child </e2> abuse
# Skipping sentence due to missing special tokens: physiotherapy was focused <e2> admission </e2> avoidance prevention deterioration after <e2> admission </e2> and facilitating early discharge
# Skipping sentence due to missing special tokens: sodium causes fluid <e2> retention </e2> which can lead edema swelling increased blood pressure and those susceptible patients congestive heart failure
# Skipping sentence due to missing special tokens: the flipflop basic element the sequential <e2> circuit </e2> and there are various structures even for the same type
# Skipping sentence due to missing special tokens: builders use paste like <e2> adhesive </e2> known the building trade mud fix the plasterboard the wall
# Skipping sentence due to missing special tokens: infection one the commonest causes <e2> death </e2> burn patients particularly
# Skipping sentence due to missing special tokens: convulsions that occur after dtap are caused <e2> fever </e2>
# Skipping sentence due to missing special tokens: fog smoke cause <e2> irritation </e2> those with respiratory sensitivity
# Skipping sentence due to missing special tokens: voters are eluded from the fundamental <e2> issues </e2>
# Skipping sentence due to missing special tokens: coconut <e2> oil </e2> extracted from the kernel meat matured coconut harvested from the coconut palm cocos nucifera
# Skipping sentence due to missing special tokens: weak ligaments are caused <e2> problems </e2> with collagen protein fibres the ligaments
# Skipping sentence due to missing special tokens: quotation used indicate the <e2> words </e2> another speaker writer
# Skipping sentence due to missing special tokens: this music was misplaced into the wrong <e2> folder </e2>
# Skipping sentence due to missing special tokens: philosophy special kind discourse that uses <e2> language </e2> order give access extralinguistic truth
# Skipping sentence due to missing special tokens: chimpanzees make <e2> tools </e2> and use them acquire foods and for social displays
# Skipping sentence due to missing special tokens: estrogen dominance one the main causes <e2> osteoporosis </e2> cancer ovarian cysts fibroids and host other female problems the
# Skipping sentence due to missing special tokens: mental disorders have often been featured <e2> art </e2> and literature
# Skipping sentence due to missing special tokens: rum distilled from fermented sugarcane <e2> juice </e2> fermented sugarcane syrup fermented molasses
# Skipping sentence due to missing special tokens: also work fiction software <e1> program </e1> written bioscientist from petersburg and finalist contest find the world first thinking computer staged yesterday reading university
# Skipping sentence due to missing special tokens: geodiversity has been added into the <e2> objective </e2>
# Skipping sentence due to missing special tokens: washer works with single cup <e2> water </e2>
# Skipping sentence due to missing special tokens: job listings india have been added our <e2> careers </e2> section
# Skipping sentence due to missing special tokens: goatfish use pair large chin <e2> barbels </e2> probe the sea bottom detect buried prey
# Skipping sentence due to missing special tokens: swelling the resin caused the <e2> expansion </e2> the structure result water other liquid molecules penetrating the matrix
# Skipping sentence due to missing special tokens: basic <e1> data </e1> entry has been added the <e1> data </e1>base
# Skipping sentence due to missing special tokens: fire was venting from the first floor multistoreyed <e2> building </e2> south mumbai nariman point area monday
# Skipping sentence due to missing special tokens: strawberry <e2> jam </e2> the perfect way use glut strawberries and easy make with this strawberry <e2> jam </e2> recipe
# Skipping sentence due to missing special tokens: sun and wind cause <e2> evaporation </e2> water causing rains and this energy can caught using hydroelectric power
# Skipping sentence due to missing special tokens: fatigue <e2> corrosion </e2> and stress <e2> corrosion </e2> are similar both are caused external stresses applied the pipe and occur inside the pipe
# Skipping sentence due to missing special tokens: previously the end machined the wrenches with highspeed steel pull <e2> broach </e2>
# Skipping sentence due to missing special tokens: assessed the efficacy recombinant <e1> vaccine </e1> consisting outersurface protein ospa without adjuvant subjects risk for lyme disease
# Skipping sentence due to missing special tokens: natural history <e2> programmes </e2> began live outside broadcasts bbc television the early
# Skipping sentence due to missing special tokens: semiconductor <e1> tech </e1> diagnoses eye disease over the internet
# Skipping sentence due to missing special tokens: historians use <e2> evidence </e2> and artifacts
# Skipping sentence due to missing special tokens: mitochondria were passed subsequent <e2> generations </e2> only through egg cells
# Skipping sentence due to missing special tokens: flyers and postcards supply current clients with <e2> company </e2> information but normally not increase clients the mailing list
# Skipping sentence due to missing special tokens: violence and corruption are spreading into this <e2> country </e2>
# Skipping sentence due to missing special tokens: the email was sent from the private <e2> account </e2> member from guarding our children against marijuana gocam
# Skipping sentence due to missing special tokens: the ark was hidden <e2> cave </e2> beneath the temple mount the very heart israel
# Skipping sentence due to missing special tokens: the <e1> envelope </e1> contained dvd her mother
# Skipping sentence due to missing special tokens: orange <e2> juice </e2> popular breakfast beverage made from the extraction squeezing liquid from fresh oranges
# Skipping sentence due to missing special tokens: vegetable <e2> oil </e2> fuel cleaner safer and less expensive alternative petroleum based fuel
# Skipping sentence due to missing special tokens: mythmaking major theme the <e2> exhibition </e2> witnessed the massive sevenpiece sculpture
# Skipping sentence due to missing special tokens: percentages denote the interest <e2> rate </e2>
# Skipping sentence due to missing special tokens: implementation this proposal being discussed the state <e2> level </e2>
# Skipping sentence due to missing special tokens: students and local residents have worked together produce <e2> bricks </e2> and the mason has completed most the work the first guest house
# Skipping sentence due to missing special tokens: smoke one the leading causes <e2> kidney </e2> failures
# Skipping sentence due to missing special tokens: all the <e1> data </e1> stored microsoft access <e1> data </e1>base
# Skipping sentence due to missing special tokens: germs are microscopic organisms that cause sickness <e2> disease </e2>
# Skipping sentence due to missing special tokens: the mother superior member the <e2> corporation </e2>
# Skipping sentence due to missing special tokens: dolphins created <e2> tools </e2> use for entertainment
# Skipping sentence due to missing special tokens: employees increasingly are turning <e2> medication </e2> and away from therapy treat depression
# Skipping sentence due to missing special tokens: the <e1> course </e1> scaled the mountain via very muddy runup
# Skipping sentence due to missing special tokens: antacids work using <e2> base </e2> neutralize the acid
# Skipping sentence due to missing special tokens: signs placed the flagpole island the village square caused <e2> stir </e2> the linglestown forum pennlivecom
# Skipping sentence due to missing special tokens: the are running into <e2> problems </e2> with the installer
# Skipping sentence due to missing special tokens: the rock roll <e1> business </e1> falling into selfparody
# Skipping sentence due to missing special tokens: discussion ensued from the florida <e2> contingent </e2> the fact that very stringent landowner protection laws florida make imperative that the highest supportable appraised vallue offered first
# Skipping sentence due to missing special tokens: cement <e2> mason </e2> means person who finishes all concrete construction such floors walls ceilings sidewalks curbs and gutters
# Skipping sentence due to missing special tokens: gotocom was idealab spinoff created the <e2> scientist </e2> and was the first company successfully provide payforplacement search service
# Skipping sentence due to missing special tokens: fats from meat and dairy cause heart <e2> disease </e2> the leading killer people with diabetes
# Skipping sentence due to missing special tokens: beer produced the brewing and fermentation <e2> starches </e2>
# Skipping sentence due to missing special tokens: teachers systematically engage students such higher order cognitive skills analysis and synthesis data using <e2> statistics </e2>
# Skipping sentence due to missing special tokens: they weave fine cloth and they use the <e1> down </e1> watersheep making called haihsipu cloth from the west the sea
# Skipping sentence due to missing special tokens: poverty caused <e2> overpopulation </e2>
# Skipping sentence due to missing special tokens: unificationists sees kingdom coming with the help the new <e2> president </e2>
# Skipping sentence due to missing special tokens: more important these changes improved the experience the <e2> software </e2>
# Skipping sentence due to missing special tokens: employees are the most important part <e2> organisation </e2>
# Skipping sentence due to missing special tokens: <e1> warehouse </e1> with limited authority can not crate the required bufferpool
# Skipping sentence due to missing special tokens: manufacturers have traditionally been more concerned about <e2> factors </e2> like price quality cycle time and not concerned over how much energy their manufacturing processes use
# Skipping sentence due to missing special tokens: time travel common theme <e2> science </e2> fiction
# Skipping sentence due to missing special tokens: scientists have assembled the first global geological <e2> map </e2> the solar system largest moon and doing have gathered new evidence into the formation the large icy satellite
# Skipping sentence due to missing special tokens: some the other stories <e1> orphan </e1> runs away from the <e1> orphan </e1>age
# Skipping sentence due to missing special tokens: frustrations threats and conflicts cause <e2> stress </e2>
# Skipping sentence due to missing special tokens: food comes from the grocery <e2> store </e2> packaged sanitized frozen chilled
# Skipping sentence due to missing special tokens: compassion was originally from <e2> people </e2> known the remote splinter group the time travelling voodoo cult faction paradox
# Skipping sentence due to missing special tokens: comments are parts the <e2> source </e2> code disregarded the compiler
# Skipping sentence due to missing special tokens: papers conductor and arranger andre kostelanetz are being donated the <e2> library </e2> the musician estate
# Skipping sentence due to missing special tokens: needs capture century <e1> criminals </e1> who have escaped timetraveling
# Skipping sentence due to missing special tokens: pigs really fly with the help <e2> trampoline </e2>
# Skipping sentence due to missing special tokens: glaucoma one the leading causes for <e2> blindness </e2> and currently about million patients worldwide are affected the disease
# Skipping sentence due to missing special tokens: <e1> wheelchair </e1> third floor flat serviced only lift
# Skipping sentence due to missing special tokens: rice <e2> spirits </e2> asia are almost always female and regarded kind mother figure thus the connection fertility and tossing the bride
# Skipping sentence due to missing special tokens: standards secondary school are criticised <e2> report </e2> the inspection body
# Skipping sentence due to missing special tokens: works this exhibition investigate humanity <e2> relationship </e2> with the world
# Skipping sentence due to missing special tokens: adenosine deaminase converts purine riboside into <e2> analog </e2> reactive intermediate
# Skipping sentence due to missing special tokens: immigrants accounted for more than half britain <e2> population </e2> growth recent years
# Skipping sentence due to missing special tokens: glaucoma group neurodegenerative <e2> disorders </e2> characterized the death retinal ganglion cells and specific deformation the optic nerve
# Skipping sentence due to missing special tokens: tax cuts for rich are thrown into <e2> doubt </e2>
# Skipping sentence due to missing special tokens: crime <e2> fiction </e2> typically and century genre dominated british and american writers
# Skipping sentence due to missing special tokens: jacks are spreading into <e2> areas </e2> formerly occupied whitetails colorado
# Skipping sentence due to missing special tokens: listeners receive wbai live over the <e2> internet </e2> referred streaming using one the various audio formats below
# Skipping sentence due to missing special tokens: has been assumed that the <e1> quench </e1> starts the middle crosssection the magnet
# Skipping sentence due to missing special tokens: ruins from <e2> years </e2> ago discovered israel show that stone age ancestors had began organize their openair living spaces into separate clusters for different activities such cooking and stone manufacturing
# Skipping sentence due to missing special tokens: the cooling processor with power <e2> usage </e2> using conventional heatsink
# Skipping sentence due to missing special tokens: they include sending emails remind customers about <e2> abandoned </e2> items
# Skipping sentence due to missing special tokens: wave crests are blown into the <e2> froth </e2>
# Skipping sentence due to missing special tokens: the <e1> nitric </e1> oxide was contained large goldplated cylinder which was ionized krypton resonance radiation
# Skipping sentence due to missing special tokens: eucharist the source the church <e2> mission </e2>
# Skipping sentence due to missing special tokens: viruses that cause respiratory <e2> illness </e2> typically are capable causing range clinical manifestations and asymptomatic infections are possible
# Skipping sentence due to missing special tokens: found the secret <e1> passages </e1> inside the monastery
# Skipping sentence due to missing special tokens: the inherent rna silencing <e1> mechanism </e1> plants has been effectively manipulated tool for the targeted downregulation genes
# Skipping sentence due to missing special tokens: brickwork masonry produced <e2> bricklayer </e2> using bricks and mortar build brick structures such walls
# Skipping sentence due to missing special tokens: citizenship was finally awarded the <e2> immigrant </e2>
# Skipping sentence due to missing special tokens: discomfort from <e2> braces </e2> similar that working out the gym the first few days you know you done something different but then the body adapts and the discomfort disappears
# Skipping sentence due to missing special tokens: because the <e1> fire </e1> was caused <e1> fire </e1>works costs associated with suppressing the <e1> fire </e1> were also applied
# Skipping sentence due to missing special tokens: workers build the <e2> comb </e2> from wax extruded from glands under their abdomen
# Skipping sentence due to missing special tokens: bed sores also known <e2> pressure </e2> sores decubitus ulcers <e2> pressure </e2> ulcers are caused <e2> pressure </e2> which cuts off blood flow parts the body
# Skipping sentence due to missing special tokens: dentists use <e2> sedation </e2> order provide anxietyfree dental experience
# Skipping sentence due to missing special tokens: cities produce surprisingly low carbon <e2> emissions </e2> per capita
# Skipping sentence due to missing special tokens: tom reynold brought his first barrel flour from detour <e1> jumper </e1> drawn
# Skipping sentence due to missing special tokens: alternators generate <e2> electricity </e2> the same principle generators
# Skipping sentence due to missing special tokens: fumbled his shirt and pulled out <e1> wad </e1> banknotes tied with string
# Skipping sentence due to missing special tokens: <e1> string </e1> packponies trotted through the pines behind them
# Skipping sentence due to missing special tokens: the <e1> music </e1> was composed <e1> music </e1>ian who was not known outside his village
# Skipping sentence due to missing special tokens: smoke from wood <e2> fires </e2> tutbury castle nottingham was considered unendurable eleanor aquitaine wife henry causing her move out
# Skipping sentence due to missing special tokens: the cooling processor with power usage using conventional <e2> heatsink </e2>
# Skipping sentence due to missing special tokens: authors use radiobuttongroup <e2> control </e2> for this purpose
# Skipping sentence due to missing special tokens: ferrets <e2> sack </e2> show more politesse
# Skipping sentence due to missing special tokens: audiences are dragged into troi counseling <e2> sessions </e2>
# Skipping sentence due to missing special tokens: radiology the branch specialty medicine that deals with the study and application <e2> imaging </e2> technology
# Skipping sentence due to missing special tokens: outbreaks caused the oral vaccine live <e2> virus </e2> have happened before
# Skipping sentence due to missing special tokens: results from this testing were presented previous technical progress <e2> report </e2> for this project
# Skipping sentence due to missing special tokens: men work inside <e2> caisson </e2> while excavating for bridge foundations
# Skipping sentence due to missing special tokens: mosquitoes are spreading into new <e2> places </e2> bringing malaria and dengue fever with them
# Skipping sentence due to missing special tokens: shirtless <e1> farmer </e1> toils plow the soil with handcultivator while his wife quietly follows with seeds for the freshly turned earth
# Skipping sentence due to missing special tokens: fish gather <e2> shoal </e2> shallow place river lake
# Skipping sentence due to missing special tokens: autonomic imbalance one the multifactorial causes essential <e2> hypertension </e2> currently
# Skipping sentence due to missing special tokens: when leaving the walk our guide gave one our group <e1> bottle </e1> with twenty rehydration tablets
# Skipping sentence due to missing special tokens: billionaires make india <e2> rich </e2> list
# Skipping sentence due to missing special tokens: acne caused <e2> clogging </e2> sebaceous oil producing glands the skin
# Skipping sentence due to missing special tokens: rabies caused <e2> virus </e2> that usually contracted through the saliva infected animal
# Skipping sentence due to missing special tokens: the man dropped off the <e1> mail </e1> into the <e1> mail </e1>box
# Skipping sentence due to missing special tokens: four stopped the cyanide train with money but with <e2> candles </e2> cups tea and homemade banners
# Skipping sentence due to missing special tokens: plane taxies from <e2> runway </e2> and stops terminal roof
# Skipping sentence due to missing special tokens: supernatant was removed into polypropylene centrifuge <e2> tube </e2>
# Skipping sentence due to missing special tokens: shrinkage from <e2> washing </e2> has always been considered serious problem for cotton knitted fabrics
# Skipping sentence due to missing special tokens: luke played the crucial role goalkeeper the <e2> team </e2> that defeated tournament favourites croatia the final match
# Skipping sentence due to missing special tokens: senior figures the sport expect the brawn cars the subject technical protest over the design their diffs rival <e2> teams </e2>
# Skipping sentence due to missing special tokens: criticism was directed its <e2> storyline </e2>
# Skipping sentence due to missing special tokens: because <e1> sports </e1> broadcast reports ongoing events within constrained physical situation contextualized reference extremely high these texts
# Skipping sentence due to missing special tokens: acne caused <e2> infections </e2> that occur when pores the skin are filled with oil dirt other substances
# Skipping sentence due to missing special tokens: employees wear <e2> sharee </e2> its sign formal dresss code
# Skipping sentence due to missing special tokens: the report about the regular <e1> road </e1> and the law
# Skipping sentence due to missing special tokens: strings the <e2> clavichord </e2> run transversely from the hitchpin rail the lefthand end tuning pegs the right
# Skipping sentence due to missing special tokens: sadness leads <e2> inspiration </e2> this story love and hate respect and betrayal learn about the history the mexican wrestling wars
# Skipping sentence due to missing special tokens: sharpening <e2> stones </e2> water <e2> stones </e2> whet<e2> stones </e2> are used grind and hone the edges steel tools and implements
# Skipping sentence due to missing special tokens: epogen made from human <e2> plasma </e2> part the blood and may contain viruses and other infectious agents that can cause disease
# Skipping sentence due to missing special tokens: bar builds guillotine out beer <e2> cans </e2> protest atlantic yards
# Skipping sentence due to missing special tokens: ovulation the exit mature <e1> ova </e1> egg from the <e1> ova </e1>ry
# Skipping sentence due to missing special tokens: details include pertinent <e2> people </e2> involved well interesting facts and production statistics
# Skipping sentence due to missing special tokens: money flows into <e2> hedge </e2> funds again
# Skipping sentence due to missing special tokens: tofu tofu bean curd soft white food made coagulating soy <e2> milk </e2>
# Skipping sentence due to missing special tokens: music used <e2> surgeons </e2> ease operations
# Skipping sentence due to missing special tokens: unemployment has been caused <e2> people </e2> who either knowingly unknowingly have priced <e2> people </e2> out jobs
# Skipping sentence due to missing special tokens: acne pimples are caused <e2> hormonal </e2> changes wrong food habits and improper skin care
# Skipping sentence due to missing special tokens: talks have moved into new <e2> topic </e2>
# Skipping sentence due to missing special tokens: bounding pulses are caused the relatively low systemic <e2> arterial </e2> blood pressure due the continuous runoff blood from the aorta into the pulmonary artery
# Skipping sentence due to missing special tokens: enrichment the soil with liquid seaweed <e2> extract </e2> has just enough alkaline effect that slugs hate
# Skipping sentence due to missing special tokens: billions euro are invested into <e2> nanotechnology </e2> europe
# Skipping sentence due to missing special tokens: they were your runofthemill poultry <e2> workers </e2> and janitors people whose chief crime was cross border arbitrarily line that determines who rich and who poor who has rights and who does
# Skipping sentence due to missing special tokens: lymphedema abnormal buildup fluid that causes <e2> swelling </e2> most often the arms legs
# Skipping sentence due to missing special tokens: religion has become the hottest <e2> topic </e2> study for united states historians
# Skipping sentence due to missing special tokens: producers planted the frozen <e2> scallops </e2> that led spike elimination from top chef
# Skipping sentence due to missing special tokens: menuactivate occurs when the accesses the menu with the <e2> keyboard </e2> mouse
# Skipping sentence due to missing special tokens: intruders are going into the <e2> organisation </e2> looking for key documents
# Skipping sentence due to missing special tokens: firefighters mark hydrants that work okay with spray <e2> paint </e2>
# Skipping sentence due to missing special tokens: rice <e2> beer </e2> famous asian country drink especially japan
# Skipping sentence due to missing special tokens: brutality was intrinsic part <e2> plantation </e2> life and child however privileged protected could escape its ugliness savagery
# Skipping sentence due to missing special tokens: engine <e2> pistons </e2> transmit the force generated the combustion gas the connecting rods
# Skipping sentence due to missing special tokens: muscles are the parts the <e2> body </e2> that allow move positions such sit stand walk run bend and reach
# Skipping sentence due to missing special tokens: menopause and pms cause stress and <e2> anxiety </e2> even without imbalanced hormones
# Skipping sentence due to missing special tokens: flashes are caused the vitreous gel <e2> tugging </e2> the retina
# Skipping sentence due to missing special tokens: bolus was injected into <e2> ports </e2> above the filter set
# Skipping sentence due to missing special tokens: concrete made from <e2> cement </e2> aggregates gravel and crush stones and water
# Skipping sentence due to missing special tokens: investment flows into emerging <e2> markets </e2>
# Skipping sentence due to missing special tokens: water <e2> erosion </e2> the detachment and removal soil material water
# Skipping sentence due to missing special tokens: lesions involving the medial part the premotor cortex the supplementary motor area sma and the rear portion the medial part the precentral gyrus caused contralateral severe legpredominant <e2> hemiplegia </e2> distally predominant and less severe proximal weakness the arm
# Skipping sentence due to missing special tokens: production and investigation such detector arose from inadequate <e2> sensitivity </e2> commercial ptype detector
# Skipping sentence due to missing special tokens: discovery consists <e2> seeing </e2> what everybody else has seen and thinking what nobody else has thought
# Skipping sentence due to missing special tokens: now you have imported the <e1> data </e1> into the region <e1> data </e1>base
# Skipping sentence due to missing special tokens: electrolysis the resulting mixture caused the <e2> reduction </e2> the aluminum ions the alo
# Skipping sentence due to missing special tokens: selforganization become apparent evolution selfassemblage the gene <e2> networks </e2> and cascades
# Skipping sentence due to missing special tokens: stings bites are caused midges horseflies bees <e2> wasps </e2> ants some spiders fleas lice etc
# Skipping sentence due to missing special tokens: conscripts spanish <e2> galleons </e2> escaped jumping ship new orleans and acapulco mexico
# Skipping sentence due to missing special tokens: pilgrimage mecca basic <e2> tenet </e2> islam
# Skipping sentence due to missing special tokens: vegetable <e2> stew </e2> delicious low calorie and healthy meal enjoy cold winter night
# Skipping sentence due to missing special tokens: electromagnets have come into <e2> use </e2>
# Skipping sentence due to missing special tokens: trauma the face and nasal area causes <e2> nosebleeds </e2> such getting punched violently slapped
# Skipping sentence due to missing special tokens: conference deals with nuclear <e2> safety </e2> environmental issues
# Skipping sentence due to missing special tokens: properties the soils developed from the <e2> amphibolites </e2> santiagoponte ulla spain
# Skipping sentence due to missing special tokens: wealth migrating into <e2> communities </e2> verde valleysedona
# Skipping sentence due to missing special tokens: negotiations between the european community and greenland fourth <e2> protocol </e2> concerning the implementation the agreement were concluded september
# Skipping sentence due to missing special tokens: garbage rapidly becoming the topic <e2> discussion </e2> business meetings political conventions and even the dinner table
# Skipping sentence due to missing special tokens: light composed <e2> particles </e2> corpuscles which are refracted accelerating into denser medium
# Skipping sentence due to missing special tokens: overpopulation and poverty cause <e2> tension </e2> not only within communities and countries but throughout the world
# Skipping sentence due to missing special tokens: astrophysicists have discovered new <e2> explanation </e2> for the early composition our solar system
# Skipping sentence due to missing special tokens: natron ingredient for making distinct <e2> color </e2> called egyptian blue
# Skipping sentence due to missing special tokens: money for communication invested into ethernet <e2> technology </e2>
# Skipping sentence due to missing special tokens: panic <e2> attacks </e2> linked heart disease and heart <e2> attacks </e2>
# Skipping sentence due to missing special tokens: tree <e2> roots </e2> that grow the surface are difficult mow walk over and can effect the growth and health nearby grass and groundcovers
# Skipping sentence due to missing special tokens: boils furuncles are caused staphylococcal bacterial <e2> infections </e2> the hair follicles
# Skipping sentence due to missing special tokens: the <e1> act </e1> applies contr<e1> act </e1>s agreements among competing manuf<e1> act </e1>urers and distributors
# Skipping sentence due to missing special tokens: your email has been successfully delivered the <e2> receiver </e2>
# Skipping sentence due to missing special tokens: however the adminstrators multi dungeon comprised primarily two factions <e2> builders </e2> and coders are the backbone mud creation
# Skipping sentence due to missing special tokens: elephants have been observed digging <e2> holes </e2> drink water and then ripping bark from tree chewing into the shape ball filling the hole and covering over with sand avoid evaporation
# Skipping sentence due to missing special tokens: violation the text associated concepts was brought into the working <e2> memory </e2> attempt resolve the violation
# Skipping sentence due to missing special tokens: malaria caused infection with <e2> parasite </e2> called plasmodium that transmitted mosquitos
# Skipping sentence due to missing special tokens: management massive salaries have already retired bailed out sinking <e2> ship </e2> leaving the masses endure the hard<e2> ship </e2> caused ignorance and mismanagement
# Skipping sentence due to missing special tokens: suspects were brought into <e2> custody </e2> for questions
# Skipping sentence due to missing special tokens: mom succeeded with cando <e2> attitude </e2>
# Skipping sentence due to missing special tokens: vinton vint cerf along with robert kahn codesigner the tcpip internet network <e2> protocol </e2>
# Skipping sentence due to missing special tokens: males had their urethra and urachus ligated with fine silastic <e2> tubing </e2>
# Skipping sentence due to missing special tokens: researchers durham university have turned video game into fire drill <e2> simulator </e2>
# Skipping sentence due to missing special tokens: the skinner <e1> box </e1> was inside large wooden ice<e1> box </e1>
# Skipping sentence due to missing special tokens: zook took the the coaching <e2> staff </e2>
# Skipping sentence due to missing special tokens: jars were then placed into three separate <e2> cages </e2>
# Skipping sentence due to missing special tokens: the election judges found <e1> ballot </e1> box some <e1> ballot </e1>s that were not the kind properly belonging they put those <e1> ballot </e1>s aside
# Skipping sentence due to missing special tokens: fish use their <e2> muscles </e2> move their bodies and fins
# Skipping sentence due to missing special tokens: designers focus more time and energy improving and differentiating their systemlevel product using <e2> megafunctions </e2>
# Skipping sentence due to missing special tokens: have inserted <e1> animation </e1> into the epost card
# Skipping sentence due to missing special tokens: birth defects are caused <e2> drugs </e2> that the persons have been exposed before birth
# Skipping sentence due to missing special tokens: rainwater falls into special <e2> use </e2>
# Skipping sentence due to missing special tokens: the <e1> film </e1> makes the point that decisionmaking important aspect such affair the heart
# Skipping sentence due to missing special tokens: allegations were made about galloway personal and financial <e2> behaviour </e2>
# Skipping sentence due to missing special tokens: toxoplasmosis caused infection with toxoplasma gondii obligate intracellular <e2> parasite </e2>
# Skipping sentence due to missing special tokens: water <e2> cistern </e2> suitable for drinking water bathing
# Skipping sentence due to missing special tokens: details new contract were under <e2> discussion </e2>
# Skipping sentence due to missing special tokens: dacryoadenitis caused local <e2> infection </e2> the lacrimal gland bacteria viruses
# Skipping sentence due to missing special tokens: debate continues swirl around the <e2> theory </e2> evolution charles darwin proposed years ago his groundbreaking book
# Skipping sentence due to missing special tokens: corn <e2> whiskey </e2> american liquor made from mash made least percent corn
# Skipping sentence due to missing special tokens: doctors treated the cancer with experimental bonemarrow transplant <e2> procedure </e2> berlin charite hospital
# Skipping sentence due to missing special tokens: treatment consists antifungal <e2> therapy </e2> surgery and supportive care
# Skipping sentence due to missing special tokens: malls are spreading into smaller <e2> towns </e2> with few precedents guide them
# Parsing 5001 of 16807
# Skipping sentence due to missing special tokens: after <e1> receipt </e1> the invoice through the airmail the email send the accounting department for payment procedures
# Skipping sentence due to missing special tokens: corruption one the main causes global <e2> crisis </e2> that deprives more than billion people access safe drinking water and more than billion access sanitation systems
# Skipping sentence due to missing special tokens: joints are parts the <e2> body </e2> where bones meet such your knee
# Skipping sentence due to missing special tokens: was first applied eating <e1> establishment </e1> around founded parisian soupseller named boulanger
# Skipping sentence due to missing special tokens: soy <e2> oil </e2> used our handmade soy candles renewable with each growing season and just one the many uses soybeans
# Skipping sentence due to missing special tokens: herds with one <e2> stallion </e2> were organized many stud farms and large number separate lines were recognized
# Skipping sentence due to missing special tokens: millions dollars are poured into <e2> research </e2> for the innermost recesses the atom
# Skipping sentence due to missing special tokens: polonium distilled from <e2> bismuth </e2> under vacuum pot provided with cover carrying condenser which positioned inside the pot
# Skipping sentence due to missing special tokens: jumbo squids are migrating into new <e2> waters </e2> and scientists wonder why
# Skipping sentence due to missing special tokens: engineers turn into methane with the help novel cellular <e2> trick </e2>
# Skipping sentence due to missing special tokens: the eightyearold boy was locked <e2> safe </e2> for prank but had rescued when his air ran short
# Skipping sentence due to missing special tokens: exposure vapor causes intense <e2> watering </e2> and irritation eyes
# Skipping sentence due to missing special tokens: democrats are running into one <e2> problem </e2> after another trying pass the health care bill the senate
# Skipping sentence due to missing special tokens: unknown source brought <e1> alien </e1> frog into our ecosystem
# Skipping sentence due to missing special tokens: parameters were obtained from eeg <e2> epochs </e2>
# Skipping sentence due to missing special tokens: injury patients the bikini accident has been caused the <e2> radiation </e2> the fallout contrast the atomic bomb injury hiroshima and nagasaki
# Skipping sentence due to missing special tokens: farmers till now have negotiated with the <e2> market </e2> individuals
# Skipping sentence due to missing special tokens: eggs come out the female <e2> body </e2> through the ovipositor
# Skipping sentence due to missing special tokens: artisans created unique <e2> footwear </e2> for rich patrons and new styles developed
# Skipping sentence due to missing special tokens: prospectors have arrived midland <e2> cars </e2>
# Skipping sentence due to missing special tokens: families are being thrown into <e2> poverty </e2> our corrupt health care system
# Skipping sentence due to missing special tokens: birds with eyes the sides their <e2> heads </e2> have wide visual field while birds with eyes the front their <e2> heads </e2> such owls have binocular vision
# Skipping sentence due to missing special tokens: honey bees have migrated into <e2> warmer </e2> areas
# Skipping sentence due to missing special tokens: scientists have succeeded creating the first <e2> transistor </e2> made from single molecule
# Skipping sentence due to missing special tokens: earthquakes are caused <e2> movement </e2> the earth crust along this fault
# Skipping sentence due to missing special tokens: the <e1> villain </e1> sweeps the ceiling with machinegun perforating milla jovovich who hiding the ceiling duct
# Skipping sentence due to missing special tokens: crime fiction the genre fiction that deals with <e2> crimes </e2> their detection criminals and their motives
# Skipping sentence due to missing special tokens: contractors quickly generate documents that are shared via fax email text message using <e2> templates </e2>
# Skipping sentence due to missing special tokens: investments have gone into the <e2> light </e2> rail
# Skipping sentence due to missing special tokens: asthma causes <e2> swelling </e2> and narrowing the airways
# Skipping sentence due to missing special tokens: mothers brought all <e2> items </e2> required dress the child bandages creams gloves all which are ridiculously expensive here
# Skipping sentence due to missing special tokens: the mahjongg set was <e2> trunk </e2> the attic all through childhood then the <e2> trunk </e2> was the garage for ten years
# Skipping sentence due to missing special tokens: billions have sunk into devastating <e2> companies </e2>
# Skipping sentence due to missing special tokens: <e1> father </e1> lunchgroup oldtimey political people called the sacramento seminar
# Skipping sentence due to missing special tokens: prospectors seeking their fortune the colorado gold fields traveled denver the smoky hill <e2> trail </e2> from kansas and points east
# Skipping sentence due to missing special tokens: ants are spreading into new <e2> habitats </e2>
# Skipping sentence due to missing special tokens: fish <e2> gills </e2> are multifunctional organs
# ...
# Skipping sentence due to missing special tokens: investigations into the real <e2> identity </e2> satoshi nakamoto were attempted the new yorker and fast company
# Skipping sentence due to missing special tokens: you are looking register multiple domains and want email <e2> account </e2> for each you can either create separate netfirms <e2> account </e2> for each domain upgrade single netfirms <e2> account </e2> hosting package
# Skipping sentence due to missing special tokens: azure cosmos multimaster configuration the game changes that really makes true global scale <e1> data </e1>base with automatic conflict resolution capabilities for <e1> data </e1> synchronization and consistancy
# Skipping sentence due to missing special tokens: being relative newcomer not comfortable with messaging other about possible <e2> problems </e2> with their systems
# Skipping sentence due to missing special tokens: government end acquire the <e2> software </e2> and documentation with only those rights set forth herein
# Skipping sentence due to missing special tokens: the department radiology has outstanding clinical <e2> imaging </e2> and research sites distributed across the stanford campus with additional sites palo alto and across the bay area
# Skipping sentence due to missing special tokens: are fully aware what <e1> data </e1>base constraints are and how they can applied ensure <e1> data </e1> integrity
# Skipping sentence due to missing special tokens: please not use email <e2> request </e2> your part
# Skipping sentence due to missing special tokens: sign receive blog posts via email and get free <e1> copy </e1> new online safety eresource
# Skipping sentence due to missing special tokens: many have learned <e1> data </e1>base design approaches from working with one <e1> data </e1>base <e1> data </e1> technology
# Skipping sentence due to missing special tokens: the ethical level will cite the ethics war barrie paskins and michael dockrill offering justification for acting war cause <e1> harm </e1> enemy even the effectiveness and proportionality the acts must remain unknown
# Skipping sentence due to missing special tokens: the united kingdom the iab affiliate council under chair matt bailey announced regulations that stated that affiliates must not use mechanism whereby are encouraged click interact with <e2> content </e2> where unclear confusing what the outcome will
# Skipping sentence due to missing special tokens: there are even <e1> data </e1> source experts who design <e1> data </e1>base and also create just what called kept treatments and triggers appropriate inside the <e1> data </e1> source
# Skipping sentence due to missing special tokens: had not been given personal emergency evacuation plan peep when checked and there was nothing specific about the evacuation permanent <e1> wheelchair </e1> the room
# Skipping sentence due to missing special tokens: here another one best money saving tips instead buying lip balm heel softener and makeup remover separately and more expensively get yourself jar coconut <e2> oil </e2> and use for all three things
# Skipping sentence due to missing special tokens: this unique tarot learning <e2> software </e2> helps and beginners understand the basics tarot card reading with learnandthentest your skills option and reference dictionary
# Skipping sentence due to missing special tokens: organic <e2> content </e2> marketing potential boon for your business involves providing the material that online are looking for
# Skipping sentence due to missing special tokens: simple convenient flexible and affordable way for keep their <e2> software </e2> date and supported and acquire new functionality developed
# Skipping sentence due to missing special tokens: <e1> data </e1>base speak call this join primary key but the <e1> data </e1> originates from multiple independent sources <e1> data </e1> fusion vldb tutorial luna dong felix naumann
# Skipping sentence due to missing special tokens: some have said that some the <e2> software </e2> causes problems especially when the drones battery low
# Skipping sentence due to missing special tokens: the voluntary identification system links unique digit number basic demographic information and biometric <e1> data </e1> such fingerprints and iris scans all which are stored central <e1> data </e1>base
# Skipping sentence due to missing special tokens: deputy labour minister unemployment rate among young <e2> people </e2> azerbaijan twice high average
# Skipping sentence due to missing special tokens: <e2> software </e2> updates are accomplished via the internet allowing quickly update their <e2> software </e2> new splice programs become available
# Skipping sentence due to missing special tokens: lucy greco has been the project spokesperson from the beginning and has fought harder for the than anyone else the team simply put dictationbridge profoundly better <e2> software </e2> package because lucys determination
# Skipping sentence due to missing special tokens: soy meal futures fell short ton and soy <e2> oil </e2> added pound
# Skipping sentence due to missing special tokens: occasionally will email members receive urgent <e2> request </e2> help such rescue animal goes missing injured animal needing urgent veterinary attention sighted
# Skipping sentence due to missing special tokens: coconut <e2> oil </e2> even benefits your skin when applied topically and has been found have antiaging regenerative effects
# Skipping sentence due to missing special tokens: youre interested adopting earlier than the pet food express bay area pet fair this year you could find the right pet for your family visiting your native pet meals categorical <e2> store </e2> studying extra about rescue teams your area beneath
# Skipping sentence due to missing special tokens: iphone comes with great looking sleek and stylish camera which shoots good quality <e1> photos </e1> the iphone camera the epitome new technology and modern looks but you miss those old days where you used capture <e1> photos </e1> and videos from your vintage old camera
# Skipping sentence due to missing special tokens: gathered adventure works sample <e1> data </e1>base from microsoft which should make for good starting base the sort <e1> data </e1> ill deal with
# Skipping sentence due to missing special tokens: dimitri comes with suite tools that allow comparison the <e1> data </e1> originating from various sensors the <e1> data </e1>base top the atmosphere toa level
# Skipping sentence due to missing special tokens: joints which move out their correct position will often cause the surrounding muscles into spasm attempt protect the joint against further damage and hold the <e2> body </e2> the most ergonomic position possible
# Skipping sentence due to missing special tokens: comment car industry worker who abused his customer <e1> data </e1>base access send <e1> data </e1> telephone scammers has been sentenced six months prison
# Skipping sentence due to missing special tokens: coconut <e2> oil </e2> also natures richest source mediumchain fatty acids mcfas also called mediumchain triglycerides mcts
# Skipping sentence due to missing special tokens: performance expectation msls expected construct home grade academic <e2> science </e2> students parents and teachers looking for grade <e2> science </e2> homework help found the below articles and tips helpful browse evening classes and full time courses
# Skipping sentence due to missing special tokens: once you have successfully submitted your <e2> account </e2> registration information you will receive email containing link that you must click order activate your <e2> account </e2>
# Skipping sentence due to missing special tokens: the data for filenames and <e2> folder </e2> names taken from cddb from text current
# Skipping sentence due to missing special tokens: you have any concerns about <e1> data </e1> stored our customer <e1> data </e1>base about our marketing strategies send email infocom
# Skipping sentence due to missing special tokens: danny legendary concert promoter knows paul mccartney jeff beck bonnie raitt infititum and has <e1> photos </e1> his iphone him and sir paul party
# Skipping sentence due to missing special tokens: occasions status <e2> usage </e2> rate loyalty status buyerreadiness stage and attitude are frequently used behavioral segments
# Skipping sentence due to missing special tokens: coconut palm <e2> oil </e2> color expeditiously transformed into getupandgo afterward travels the liver
# Skipping sentence due to missing special tokens: breakthrough initiatives are developing open source <e2> software </e2> assist understanding and analyzing the data which are available github under ucberkeleyseti
# Skipping sentence due to missing special tokens: gregory was <e1> music </e1> genious <e1> music </e1>ian and teacher <e1> music </e1> deep mystic the art <e1> music </e1> both ecclesiastical and external
# Skipping sentence due to missing special tokens: under circumstances shall wwwzeetelevisionasiacom responsible for any loss damage including personal injury death resulting from use the services attendance event wwwzeetelevisionasiacom from any <e2> content </e2> posted through the wwwzeetelevisionasiacom services from the conduct any the wwwzeetelevisionasiacom whether online offline
# Parsing 15001 of 16807
# Skipping sentence due to missing special tokens: they have <e1> data </e1>base with about million records and then need help exporting some the <e1> data </e1> excel
# Skipping sentence due to missing special tokens: coconut <e2> oil </e2> has actually been shown help optimize body weight which can dramatically reduce your risk developing type diabetes
# Skipping sentence due to missing special tokens: all <e1> photos </e1> are taken cannon either husband mom but this method editing can done images from dslr from iphone just the same
# Skipping sentence due to missing special tokens: once you have received the confirmation email and activated your online <e2> account </e2> you can log your online <e2> account </e2> from the provider loginbackground checks page
# Skipping sentence due to missing special tokens: first <e1> photos </e1> the iphone were obtained blogger who guessed the correct urls
# Skipping sentence due to missing special tokens: contact verified sunflower seed dehulling machine for cooking <e2> oil </e2> provide experienced malaysia tpd crude palm kernel <e2> oil </e2> bleaching refinery for
# Skipping sentence due to missing special tokens: great web constructing company should start with questionnaire related everything from style style <e2> content </e2> well concentrate website goals for through the planning stage
# Skipping sentence due to missing special tokens: clicking submit you agree that sprint sprint authorized business representative may possibly get touch with you about your <e2> request </e2> and that sprint might also send you added info about business solutions and other service and solution promotions the email address offered
# Skipping sentence due to missing special tokens: own five blogs about crime <e2> fiction </e2> italian language and english language and classical music
# Skipping sentence due to missing special tokens: this <e2> software </e2> offers solution for who wants record the audio their skype calls
# Skipping sentence due to missing special tokens: opera free web browser and email <e2> manager </e2> that offers many advanced features
# Skipping sentence due to missing special tokens: you acknowledge and agree that providing gold line with any personal proprietary information through the website you consent the transmission such personal proprietary information over international borders necessary for processing accordance with gold lines <e2> standard </e2> business practices
# Skipping sentence due to missing special tokens: dictationbridge uses free <e2> software </e2> model will free and available cost end forever blind person can get themselves laptop flea market emerging nation and with nvda and dictationbridge able use speech recognition cost they can easily afford
# Skipping sentence due to missing special tokens: please aware that may provide links third party web sites from the site service its and are not responsible for the <e2> content </e2> information collection practices those sites
# Skipping sentence due to missing special tokens: order quickly identify the correct <e2> content </e2> and websites that will meet their needs almost all will use search engine such google
# Skipping sentence due to missing special tokens: suicide among teens often occurs after stressful event such breakup <e2> death </e2> the family
# Skipping sentence due to missing special tokens: vietnam thailand malaysia and the philippines are among the upcoming markets with fastgrowing internet populations and <e1> tech </e1> savvy consumers
# Skipping sentence due to missing special tokens: promoted semrush how use spin rewriter silesian university opava testmonials cancer hrs ago people become paying save all your work and edit later needed follow pets ads pride ourselves not only offering top quality product easily the best product the <e2> content </e2> spinning market
# Skipping sentence due to missing special tokens: essentially you are looking for <e2> content </e2> that will engage over period time while also providing platform encourage sales your product service visits your website
# Skipping sentence due to missing special tokens: glaucoma leading cause <e2> blindness </e2> the world
# Skipping sentence due to missing special tokens: each netfirms <e2> account </e2> includes free email <e2> account </e2> unless you upgrade hosting package
# Skipping sentence due to missing special tokens: needed consider our beyond mobile well consider the needs our colleagues designing <e2> software </e2> the medical provider side which more internalenterprise experience
# Skipping sentence due to missing special tokens: you decide remove the <e2> standard </e2> microsoft access navigation options from your database forms which also removes the microsoft access record counters would good idea include your own custom designs that the database can see what record they are currently and how many records are contained the database table
# Skipping sentence due to missing special tokens: place your alternate <e2> content </e2> here and without the flash plugin with javascript turned off will see this
# Skipping sentence due to missing special tokens: gilead and gilead representatives shall not held responsible for any action taken that based the information presented this gilead website and all this gilead website agree that all access and use this gilead website and any and all <e2> content </e2> presented this gilead website the own risk
# Skipping sentence due to missing special tokens: the highpowered flash flash<e1> light </e1> has three more modes stable front beam flashing back end <e1> light </e1> and combination all both
# Skipping sentence due to missing special tokens: the email form feature this board includes safeguards try and track who send such posts email the board administrator with full <e1> copy </e1> the email you received
# Skipping sentence due to missing special tokens: the best mac video <e2> software </e2> ever allowing easily convert and edit videos including videos well homemade dvds mac
# Skipping sentence due to missing special tokens: use first party and third party cookies enhance your experience this site and understand how interact with our <e2> content </e2> and view our advertising
# Skipping sentence due to missing special tokens: weak links the system however can produce assorted <e2> problems </e2> leading loss value and shortened component life
# Parsing 16807 of 16807
#
# Number of sentences left after removing invalid ones: 16200
# Converting sentence...
# Parsing 2717 of 2717
#
# Number of sentences left after removing invalid ones: 2717

# %% [markdown]
# Evaluation Metrics

# %%
def evaluate(model, device, test_loader):
    eval_loss = 0.0
    nb_eval_steps = 0
    preds = None
    out_label_ids = None

    model.eval()

    for batch in tqdm(test_loader, desc="Evaluating"):
        batch = tuple(t.to(device) for t in batch)
        with torch.no_grad():
            inputs = {'input_ids': batch[0],
                      'attention_mask': batch[1],
                      'labels': batch[2],
                      'e1_mask': batch[3],
                      'e2_mask': batch[4]}
            outputs = model(**inputs)
            tmp_eval_loss, logits = outputs[:2]

            eval_loss += tmp_eval_loss.mean().item()
        nb_eval_steps += 1

        if preds is None:
            preds = logits.detach().cpu().numpy()
            out_label_ids = inputs['labels'].detach().cpu().numpy()
        else:
            preds = np.append(preds, logits.detach().cpu().numpy(), axis=0)
            out_label_ids = np.append(
                out_label_ids, inputs['labels'].detach().cpu().numpy(), axis=0)

    eval_loss = eval_loss / nb_eval_steps
    preds = np.argmax(preds, axis=1)

    result = {'accuracy' : accuracy_score(out_label_ids, preds), 'f1_score': f1_score(out_label_ids, preds, average='macro'), 'pred' : preds}
    return result

def save_model():
    torch.save(model.state_dict(), 'relation_data/trained_models/model.bin')

def load_saved_model(args):
  tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
  tokenizer.add_special_tokens({"additional_special_tokens" : ADDITIONAL_SPECIAL_TOKENS})

  config = RobertaConfig.from_pretrained('roberta-base', num_labels = args['NUM_LABELS'])
  model = RBERT.from_pretrained('relation_data/trained_models/model.bin', config=config, args=args)

  model.cuda()
  return config, tokenizer, model

# %% [markdown]
# Model Training

# %%
t_total = len(train_loader) // args['GRADIENT_ACCUMULATION_STEPS'] * args['EPOCHS']

# Prepare optimizer and schedule (linear warmup and decay)
no_decay = ['bias', 'LayerNorm.weight']
optimizer_grouped_parameters = [
    {'params': [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)],
      'weight_decay': args['WEIGHT_DECAY']},
    {'params': [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)], 'weight_decay': 0.0}
]
optimizer = AdamW(optimizer_grouped_parameters, lr=args['LEARNING_RATE'], eps=args['ADAM_EPSILON'])
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=args['NUM_WARMUP_STEPS'], num_training_steps=t_total)


global_step = 0
tr_loss = 0.0
model.zero_grad()
train_iterator = trange(int(args['EPOCHS']), desc="Epoch")

for _ in train_iterator:
    epoch_iterator = tqdm(train_loader, desc="Iteration")
    for step, batch in enumerate(epoch_iterator):
        model.train()
        batch = tuple(t.to(device) for t in batch)  # GPU or CPU
        inputs = {'input_ids': batch[0],
                  'attention_mask': batch[1],
                  'labels': batch[2],
                  'e1_mask': batch[3],
                  'e2_mask': batch[4]}
        outputs = model(**inputs)
        loss = outputs[0]

        loss.backward()

        tr_loss += loss.item()
        torch.nn.utils.clip_grad_norm_(model.parameters(), args['MAX_GRAD_NORM'])
        optimizer.step()
        scheduler.step()  # Update learning rate schedule
        model.zero_grad()


    print("\n====Evaluation====")
    print("\nACCURACY: ", evaluate(model, device, test_loader)['accuracy'])
# Out:
# Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/1013 [00:00<?, ?it/s]
# Iteration:   0%|          | 1/1013 [00:02<41:08,  2.44s/it]
# Iteration:   0%|          | 2/1013 [00:03<27:15,  1.62s/it]
# Iteration:   0%|          | 3/1013 [00:04<22:49,  1.36s/it]
# Iteration:   0%|          | 4/1013 [00:05<20:48,  1.24s/it]
# Iteration:   0%|          | 5/1013 [00:06<19:39,  1.17s/it]
# Iteration:   1%|          | 6/1013 [00:07<18:58,  1.13s/it]
# Iteration:   1%|          | 7/1013 [00:08<18:34,  1.11s/it]
# Iteration:   1%|          | 8/1013 [00:09<18:19,  1.09s/it]
# Iteration:   1%|          | 9/1013 [00:10<18:08,  1.08s/it]
# Iteration:   1%|          | 10/1013 [00:11<18:01,  1.08s/it]
# Iteration:   1%|          | 11/1013 [00:13<18:00,  1.08s/it]
# Iteration:   1%|          | 12/1013 [00:14<17:59,  1.08s/it]
# Iteration:   1%|▏         | 13/1013 [00:15<17:57,  1.08s/it]
# Iteration:   1%|▏         | 14/1013 [00:16<17:57,  1.08s/it]
# Iteration:   1%|▏         | 15/1013 [00:17<17:58,  1.08s/it]
# Iteration:   2%|▏         | 16/1013 [00:18<17:59,  1.08s/it]
# Iteration:   2%|▏         | 17/1013 [00:19<17:59,  1.08s/it]
# Iteration:   2%|▏         | 18/1013 [00:20<17:57,  1.08s/it]
# Iteration:   2%|▏         | 19/1013 [00:21<17:57,  1.08s/it]
# Iteration:   2%|▏         | 20/1013 [00:22<17:57,  1.08s/it]
# Iteration:   2%|▏         | 21/1013 [00:23<17:53,  1.08s/it]
# Iteration:   2%|▏         | 22/1013 [00:24<17:49,  1.08s/it]
# Iteration:   2%|▏         | 23/1013 [00:25<17:45,  1.08s/it]
# Iteration:   2%|▏         | 24/1013 [00:27<17:41,  1.07s/it]
# Iteration:   2%|▏         | 25/1013 [00:28<17:37,  1.07s/it]
# Iteration:   3%|▎         | 26/1013 [00:29<17:34,  1.07s/it]
# Iteration:   3%|▎         | 27/1013 [00:30<17:30,  1.07s/it]
# Iteration:   3%|▎         | 28/1013 [00:31<17:26,  1.06s/it]
# Iteration:   3%|▎         | 29/1013 [00:32<17:21,  1.06s/it]
# Iteration:   3%|▎         | 30/1013 [00:33<17:18,  1.06s/it]
# Iteration:   3%|▎         | 31/1013 [00:34<17:14,  1.05s/it]
# Iteration:   3%|▎         | 32/1013 [00:35<17:11,  1.05s/it]
# Iteration:   3%|▎         | 33/1013 [00:36<17:10,  1.05s/it]
# Evaluating:  85%|████████▍ | 72/85 [00:42<00:07,  1.69it/s]
# Evaluating:  86%|████████▌ | 73/85 [00:43<00:07,  1.69it/s]
# Evaluating:  87%|████████▋ | 74/85 [00:43<00:06,  1.69it/s]
# Evaluating:  88%|████████▊ | 75/85 [00:44<00:05,  1.68it/s]
# Evaluating:  89%|████████▉ | 76/85 [00:45<00:05,  1.69it/s]
# Evaluating:  91%|█████████ | 77/85 [00:45<00:04,  1.69it/s]
# Evaluating:  92%|█████████▏| 78/85 [00:46<00:04,  1.69it/s]
# Evaluating:  93%|█████████▎| 79/85 [00:46<00:03,  1.69it/s]
# Evaluating:  94%|█████████▍| 80/85 [00:47<00:02,  1.69it/s]
# Evaluating:  95%|█████████▌| 81/85 [00:48<00:02,  1.69it/s]
# Evaluating:  96%|█████████▋| 82/85 [00:48<00:01,  1.69it/s]
# Evaluating:  98%|█████████▊| 83/85 [00:49<00:01,  1.69it/s]
# Evaluating:  99%|█████████▉| 84/85 [00:49<00:00,  1.69it/s]
# Evaluating: 100%|██████████| 85/85 [00:50<00:00,  1.69it/s]
# Epoch: 100%|██████████| 5/5 [1:31:29<00:00, 1097.89s/it]
# ACCURACY:  0.8295914611704085

# %% [markdown]
# Model result on test data

# %%
result = evaluate(model, device, test_loader)
print("\nAccuracy: {}\nF1-score:{}".format(result['accuracy'], result['f1_score']))
# labels.iloc[result['pred']].values
# Out:
# Evaluating: 100%|██████████| 85/85 [00:50<00:00,  1.68it/s]
# Accuracy: 0.8295914611704085
# F1-score:0.7977865887682739

# %% [markdown]
# Save model

# %%
torch.save(model, 'model.pt')

# %% [markdown]
# Official F1 score metric without 'Other' class

# %%
def evaluate_f1_excluding_classes(model, device, test_loader, excluded_classes=[]):
    """
    Evaluates the model on F1 score excluding specific classes.

    Parameters:
    - model: The trained model.
    - device: Device (cpu or cuda).
    - test_loader: DataLoader for the test set.
    - excluded_classes: List of class labels to exclude from the evaluation.

    Returns:
    - result: A dictionary containing the accuracy and F1 score.
    """
    eval_loss = 0.0
    nb_eval_steps = 0
    preds = None
    out_label_ids = None

    model.eval()

    for batch in tqdm(test_loader, desc="Evaluating"):
        batch = tuple(t.to(device) for t in batch)
        with torch.no_grad():
            inputs = {'input_ids': batch[0],
                      'attention_mask': batch[1],
                      'labels': batch[2],
                      'e1_mask': batch[3],
                      'e2_mask': batch[4]}
            outputs = model(**inputs)
            tmp_eval_loss, logits = outputs[:2]

            eval_loss += tmp_eval_loss.mean().item()
        nb_eval_steps += 1

        if preds is None:
            preds = logits.detach().cpu().numpy()
            out_label_ids = inputs['labels'].detach().cpu().numpy()
        else:
            preds = np.append(preds, logits.detach().cpu().numpy(), axis=0)
            out_label_ids = np.append(out_label_ids, inputs['labels'].detach().cpu().numpy(), axis=0)

    eval_loss = eval_loss / nb_eval_steps
    preds = np.argmax(preds, axis=1)

    # Mask out the excluded classes from the predictions and labels
    mask = np.isin(out_label_ids, excluded_classes, invert=True)  # Mask out the excluded classes
    filtered_preds = preds[mask]
    filtered_labels = out_label_ids[mask]

    # Calculate F1 score excluding the specified classes
    f1 = f1_score(filtered_labels, filtered_preds, average='macro')

    result = {'f1_score': f1, 'pred': filtered_preds}
    return result

# %% [markdown]
# Improved f1 score (18 classes) for the approach

# %%
result1 = evaluate_f1_excluding_classes(model, device, test_loader, excluded_classes=[0])
print("\nF1-score (excluding class 0):", result1['f1_score'])
# Out:
# Evaluating: 100%|██████████| 85/85 [00:50<00:00,  1.67it/s]
# F1-score (excluding class 0): 0.8054423006727647
